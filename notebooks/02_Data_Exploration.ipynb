# %%
# UrbanIQ 🚀
# Stage 2: Data Exploration

print("UrbanIQ Data Exploration Started 🚀")
# Out:
# UrbanIQ Data Exploration Started 🚀

# %%
import pandas as pd
import numpy as np

print("Libraries loaded successfully ✅")
# Out:
# Libraries loaded successfully ✅

# %%
import os

print("Current location:")
print(os.getcwd())

print("\nProject files:")
for item in os.listdir(".."):
    print(item)
# Out:
# Current location:
# C:\Users\sanja\UrbanIQ\notebooks
#
# Project files:
# .git
# .gitattributes
# .gitignore
# .ipynb_checkpoints
# dashboard
# data
# images
# notebooks
# README.md
# requirements.txt
# sql

# %%
import os

print("Checking data folders:")

print("raw folder exists:", os.path.exists("../data/raw"))
print("processed folder exists:", os.path.exists("../data/processed"))
# Out:
# Checking data folders:
# raw folder exists: True
# processed folder exists: True

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd

# Load Bengaluru rental dataset
file_path = "../data/raw/bengaluru_rent.csv"

df = pd.read_csv(file_path)

print("Dataset loaded successfully ✅")
# Out:
# Dataset loaded successfully ✅

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
import pandas as pd

df = pd.read_csv("../data/raw/bengaluru_rent.csv")
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/bengaluru_rent.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
import pandas as pd

df = pd.read_csv("../data/raw/bengaluru_rent.csv")
print("Dataset Loaded Successfully ✅")
# Out:
# Dataset Loaded Successfully ✅

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(529)

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df = df.drop("society", axis=1)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'total_sqft', 'bath',
#        'balcony', 'price'],
#       dtype='object')

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (12752, 8)

# %% [markdown]
# ## Data Cleaning - Step 2
#
# ### Remove Duplicate Rows
#
# **Reason:**
#
# Duplicate records can bias analysis and produce inaccurate results. Removing them ensures that each property listing is counted only once.

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (12752, 8)

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         605
# price             0
# dtype: int64

# %%
df = df.dropna(subset=["location", "size"])

# %% [markdown]
# df.shape

# %% [markdown]
# ## Data Cleaning - Step 3
#
# ### Handle Missing Values
#
# **Reason:**
#
# The `location` and `size` columns are essential for housing analysis. Since only a small number of records had missing values, those rows were removed to maintain data quality.

# %% [markdown]
# df["bath"].describe()

# %%
df["balcony"].describe()
# Out:
# count    12146.000000
# mean         1.582496
# std          0.823384
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: balcony, dtype: float64

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# total_sqft        0
# bath             57
# balcony         589
# price             0
# dtype: int64

# %% [markdown]
# ## Data Cleaning - Step 4
#
# ### Fill Missing Values
#
# **Reason:**
#
# The `bath` and `balcony` columns contained a small number of missing values. Instead of removing these records, the missing values were replaced with the median because it is less affected by extreme values than the mean.

# %%
# Fill missing values using median
df["bath"] = df["bath"].fillna(df["bath"].median())
df["balcony"] = df["balcony"].fillna(df["balcony"].median())

# %%
# Fill missing values using median
df["bath"] = df["bath"].fillna(df["bath"].median())
df["balcony"] = df["balcony"].fillna(df["balcony"].median())

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
2100
1200-1400
34.46Sq. Meter
4125Perch
# Out:
#   Cell In[37], line 3
#     34.46Sq. Meter
#         ^
# SyntaxError: invalid decimal literal

# %%
# Fill missing values using the median
df["bath"] = df["bath"].fillna(df["bath"].median())
df["balcony"] = df["balcony"].fillna(df["balcony"].median())

# %%
# Fill missing values using the median
df["bath"] = df["bath"].fillna(df["bath"].median())
df["balcony"] = df["balcony"].fillna(df["balcony"].median())

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# 3       1521   3.0      1.0   95.00
# 4       1200   2.0      1.0   51.00

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       shape=(2110,), dtype=object)

# %%
df["total_sqft"].sample(20, random_state=42)
# Out:
# 12590    1162
# 12309    1062
# 3760     1571
# 2272     3245
# 2554     1465
# 3000     2350
# 173      1350
# 1352     5000
# 8544     1209
# 1162     1200
# 1819     1188
# 8263     1255
# 7620     1200
# 8716     1499
# 7641     1625
# 7304     1560
# 7771     1010
# 2583     1304
# 4269     3295
# 6365      625
# Name: total_sqft, dtype: object

# %%
df["total_sqft"].dtype
# Out:
# dtype('O')

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df[~df["total_sqft"].apply(is_float)].head(20)
# Out:
#                 area_type   availability               location       size  \
# 30   Super built-up  Area         19-Dec              Yelahanka      4 BHK
# 56         Built-up  Area         20-Feb            Devanahalli  4 Bedroom
# 81         Built-up  Area         18-Oct            Hennur Road  4 Bedroom
# 122  Super built-up  Area         18-Mar                 Hebbal      4 BHK
# 137  Super built-up  Area         19-Mar     8th Phase JP Nagar      2 BHK
# 165  Super built-up  Area         18-Dec               Sarjapur      2 BHK
# 188  Super built-up  Area  Ready To Move               KR Puram      2 BHK
# 224  Super built-up  Area         19-Dec            Devanahalli      3 BHK
# 410  Super built-up  Area  Ready To Move                Kengeri      1 BHK
# 549  Super built-up  Area         18-Sep            Hennur Road      2 BHK
# 648        Built-up  Area  Ready To Move                Arekere  9 Bedroom
# ...

# %%
def is_float(x):
# Out:
#   Cell In[47], line 1
#     def is_float(x):
#                     ^
# _IncompleteInputError: incomplete input

# %%
def is_float(x):
    try:
        float(x)
        return True
    except:
        return False

# %%
df[~df["total_sqft"].apply(is_float)].head(20)
# Out:
#                 area_type   availability               location       size  \
# 30   Super built-up  Area         19-Dec              Yelahanka      4 BHK
# 56         Built-up  Area         20-Feb            Devanahalli  4 Bedroom
# 81         Built-up  Area         18-Oct            Hennur Road  4 Bedroom
# 122  Super built-up  Area         18-Mar                 Hebbal      4 BHK
# 137  Super built-up  Area         19-Mar     8th Phase JP Nagar      2 BHK
# 165  Super built-up  Area         18-Dec               Sarjapur      2 BHK
# 188  Super built-up  Area  Ready To Move               KR Puram      2 BHK
# 224  Super built-up  Area         19-Dec            Devanahalli      3 BHK
# 410  Super built-up  Area  Ready To Move                Kengeri      1 BHK
# 549  Super built-up  Area         18-Sep            Hennur Road      2 BHK
# 648        Built-up  Area  Ready To Move                Arekere  9 Bedroom
# ...

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')

    if len(tokens) == 2:
        return (float(tokens[0]) + float(tokens[1])) / 2

    try:
        return float(x)
    except:
        return None

# %%
df["total_sqft"] = df["total_sqft"].apply(convert_sqft_to_num)

# %%
df["total_sqft"].head(20)
# Out:
# 0     1056.0
# 1     2600.0
# 2     1440.0
# 3     1521.0
# 4     1200.0
# 5     1170.0
# 6     2732.0
# 7     3300.0
# 8     1310.0
# 9     1020.0
# 10    1800.0
# 11    2785.0
# 12    1000.0
# 13    1100.0
# 14    2250.0
# 15    1175.0
# 16    1180.0
# 17    1540.0
# 18    2770.0
# 19    1100.0
# Name: total_sqft, dtype: float64

# %%
df["total_sqft"].isnull().sum()
# Out:
# np.int64(46)

# %%
## Data Cleaning - Step 5

### Clean `total_sqft`

**Reason:**

The `total_sqft` column contained values in multiple formats, including ranges and different measurement units. Ranges were converted to their average value. Rows with unsupported units were removed because they represented less than 0.4% of the dataset and would otherwise require extensive unit conversions.
# Out:
#   Cell In[54], line 5
#     **Reason:**
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Data Cleaning - Step 5
#
# ### Clean `total_sqft`
#
# **Reason:**
#
# The `total_sqft` column contained values in multiple formats, including ranges and different measurement units. Ranges were converted to their average value. Rows with unsupported units were removed because they represented less than 0.4% of the dataset and would otherwise require extensive unit conversions.

# %%
df = df.dropna(subset=["total_sqft"])

# %%
df.shape
# Out:
# (12689, 8)

# %%
df = df.dropna(subset=["total_sqft"])

# %% [markdown]
# df.shape

# %% [markdown]
# ## Feature Engineering
#
# ### Step 1: Extract BHK
#
# **Reason:**
#
# The `size` column contains both the number of rooms and text (BHK/Bedroom). Extracting only the numeric value creates a structured feature that can be used for analysis and modeling.

# %%
df["bhk"] = df["size"].apply(lambda x: int(x.split(" ")[0]))

# %%
df[["size", "bhk"]].head(10)
# Out:
#         size  bhk
# 0      2 BHK    2
# 1  4 Bedroom    4
# 2      3 BHK    3
# 3      3 BHK    3
# 4      2 BHK    2
# 5      2 BHK    2
# 6      4 BHK    4
# 7      4 BHK    4
# 8      3 BHK    3
# 9  6 Bedroom    6

# %%
lambda
# Out:
#   Cell In[60], line 1
#     lambda
#           ^
# SyntaxError: invalid syntax

# %%
lambda x: int(x.split(" ")[0])
# Out:
# <function __main__.<lambda>(x)>

# %%
df["bhk"] = df["size"].apply(lambda x: int(x.split(" ")[0]))

# %% [markdown]
# df[["size", "bhk"]].head(10)

# %% [markdown]
# ## Feature Engineering - Step 2
#
# ### Calculate Price Per Square Foot
#
# **Reason:**
#
# Price per square foot is a standard real estate metric used to compare properties of different sizes. It provides a fair comparison of property values across locations.

# %%
df["price_per_sqft"] = (df["price"] * 100000) / df["total_sqft"]

# %%
df[["price", "total_sqft", "price_per_sqft"]].head(10)
# Out:
#     price  total_sqft  price_per_sqft
# 0   39.07      1056.0     3699.810606
# 1  120.00      2600.0     4615.384615
# 2   62.00      1440.0     4305.555556
# 3   95.00      1521.0     6245.890861
# 4   51.00      1200.0     4250.000000
# 5   38.00      1170.0     3247.863248
# 6  204.00      2732.0     7467.057101
# 7  600.00      3300.0    18181.818182
# 8   63.25      1310.0     4828.244275
# 9  370.00      1020.0    36274.509804

# %%
df["price_per_sqft"] = (df["price"] * 100000) / df["total_sqft"]

# %%
df[["price", "total_sqft", "price_per_sqft"]].head(10)
# Out:
#     price  total_sqft  price_per_sqft
# 0   39.07      1056.0     3699.810606
# 1  120.00      2600.0     4615.384615
# 2   62.00      1440.0     4305.555556
# 3   95.00      1521.0     6245.890861
# 4   51.00      1200.0     4250.000000
# 5   38.00      1170.0     3247.863248
# 6  204.00      2732.0     7467.057101
# 7  600.00      3300.0    18181.818182
# 8   63.25      1310.0     4828.244275
# 9  370.00      1020.0    36274.509804

# %%
df["price_per_sqft"].describe()
# Out:
# count    1.268900e+04
# mean     8.039058e+03
# std      1.088525e+05
# min      2.678298e+02
# 25%      4.300000e+03
# 50%      5.490196e+03
# 75%      7.407407e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
df["price_per_sqft"].sort_values(ascending=False).head(10)
# Out:
# 4086     1.200000e+07
# 4972     2.300000e+06
# 349      6.727273e+05
# 1122     6.250000e+05
# 11558    3.633333e+05
# 1020     2.000000e+05
# 7657     1.764706e+05
# 7088     7.692308e+04
# 6421     7.653061e+04
# 12443    5.977011e+04
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# ## Feature Engineering - Step 3
#
# ### Investigate Price per Square Foot
#
# **Reason:**
#
# Before identifying outliers, it is important to understand the distribution of the `price_per_sqft` feature. This helps distinguish realistic high-value properties from potential data quality issues.

# %%
df.loc[4086]
# Out:
# area_type             Plot  Area
# availability       Ready To Move
# location          Sarjapur  Road
# size                   4 Bedroom
# total_sqft                   1.0
# bath                         4.0
# balcony                      2.0
# price                      120.0
# bhk                            4
# price_per_sqft        12000000.0
# Name: 4086, dtype: object

# %%
df.loc[4086]
# Out:
# area_type             Plot  Area
# availability       Ready To Move
# location          Sarjapur  Road
# size                   4 Bedroom
# total_sqft                   1.0
# bath                         4.0
# balcony                      2.0
# price                      120.0
# bhk                            4
# price_per_sqft        12000000.0
# Name: 4086, dtype: object

# %% [markdown]
# ## Feature Engineering - Step 4
#
# ### Create Square Feet per BHK
#
# **Reason:**
#
# To identify unrealistic property listings, we calculate the average area available per bedroom. Properties with extremely low square footage per bedroom may indicate data quality issues.

# %%
df["sqft_per_bhk"] = df["total_sqft"] / df["bhk"]

# %%
df[["bhk", "total_sqft", "sqft_per_bhk"]].head()
# Out:
#    bhk  total_sqft  sqft_per_bhk
# 0    2      1056.0         528.0
# 1    4      2600.0         650.0
# 2    3      1440.0         480.0
# 3    3      1521.0         507.0
# 4    2      1200.0         600.0

# %%
df[df["sqft_per_bhk"] < 300].head(20)
# Out:
#                 area_type   availability              location       size  \
# 9              Plot  Area  Ready To Move          Gandhi Bazar  6 Bedroom
# 45             Plot  Area  Ready To Move            HSR Layout  8 Bedroom
# 58             Plot  Area  Ready To Move         Murugeshpalya  6 Bedroom
# 68             Plot  Area  Ready To Move   Devarachikkanahalli  8 Bedroom
# 70             Plot  Area  Ready To Move           Double Road  3 Bedroom
# 78         Built-up  Area  Ready To Move      Kaval Byrasandra      2 BHK
# 89             Plot  Area  Ready To Move          Rajaji Nagar  6 Bedroom
# 119            Plot  Area  Ready To Move           Hennur Road  2 Bedroom
# 129            Plot  Area  Ready To Move    Vishwapriya Layout  7 Bedroom
# 149            Plot  Area  Ready To Move                Dinnur  6 Bedroom
# 170  Super built-up  Area  Ready To Move  Kothnur Narayanapura      6 BHK
# 176            Plot  Area  Ready To Move    Kumaraswami Layout  5 Bedroom
# ...

# %% [markdown]
# ## Feature Engineering - Step 5
#
# ### Remove Unrealistic Properties
#
# **Reason:**
#
# Properties with less than **300 square feet per bedroom** are considered unrealistic for residential housing. These records are treated as potential data quality issues and are removed before analysis.

# %%
df = df[df["sqft_per_bhk"] >= 300]

# %%
df.shape
# Out:
# (11955, 11)

# %%
df[df["sqft_per_bhk"] < 300]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, total_sqft, bath, balcony, price, bhk, price_per_sqft, sqft_per_bhk]
# Index: []

# %% [markdown]
# ## Feature Engineering - Step 6
#
# ### Analyze Location Frequency
#
# **Reason:**
#
# The dataset contains many unique locations. Some locations have only a few property listings, making statistical analysis unreliable. Locations with very few records will later be grouped into **"Other"** to improve the quality of analysis.

# %%
df["location"] = df["location"].str.strip()

# %%
location_stats = df.groupby("location")["location"].count().sort_values(ascending=False)

# %%
location_stats.head(20)
# Out:
# location
# Whitefield                  520
# Sarjapur  Road              373
# Electronic City             280
# Kanakpura Road              238
# Thanisandra                 230
# Yelahanka                   204
# Marathahalli                164
# Hebbal                      160
# Raja Rajeshwari Nagar       158
# Uttarahalli                 148
# Bannerghatta Road           147
# Hennur Road                 145
# 7th Phase JP Nagar          129
# Electronic City Phase II    122
# Rajaji Nagar                101
# Haralur Road                 98
# Bellandur                    92
# Electronics City Phase 1     87
# KR Puram                     83
# Hoodi                        83
# Name: location, dtype: int64

# %%
len(location_stats)
# Out:
# 1205

# %%
len(location_stats[location_stats <= 10])
# Out:
# 991

# %% [markdown]
# ## Feature Engineering - Step 7
#
# ### Group Rare Locations
#
# **Reason:**
#
# Some locations have very few property listings, making meaningful analysis difficult. These low-frequency locations are grouped into **"Other"** to reduce noise and improve statistical analysis.

# %%
location_stats_less_than_10 = location_stats[location_stats <= 10]

# %%
len(location_stats_less_than_10)
# Out:
# 991

# %%
df["location"] = df["location"].apply(
    lambda x: "Other" if x in location_stats_less_than_10 else x
)

# %%
len(df["location"].unique())
# Out:
# 215

# %%
df["location"].value_counts().head(20)
# Out:
# location
# Other                       2758
# Whitefield                   520
# Sarjapur  Road               373
# Electronic City              280
# Kanakpura Road               238
# Thanisandra                  230
# Yelahanka                    204
# Marathahalli                 164
# Hebbal                       160
# Raja Rajeshwari Nagar        158
# Uttarahalli                  148
# Bannerghatta Road            147
# Hennur Road                  145
# 7th Phase JP Nagar           129
# Electronic City Phase II     122
# Rajaji Nagar                 101
# Haralur Road                  98
# Bellandur                     92
# Electronics City Phase 1      87
# Hoodi                         83
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Objective
#
# The goal of Exploratory Data Analysis is to understand trends, patterns, and relationships in the Bengaluru housing dataset through statistical summaries and visualizations. These insights will support business decisions and the development of the CityLife Score.

# %%
plt.figure(figsize=(10,6))
plt.hist(df["price"], bins=50)

plt.title("Distribution of House Prices")
plt.xlabel("Price (Lakhs)")
plt.ylabel("Number of Properties")

plt.show()

# %% [markdown]
# ### Business Insight
#
# Most properties are concentrated in the lower price range, while a small number of luxury properties create a long right tail. This indicates that the housing market is positively skewed.

# %%
df["bhk"].value_counts().sort_index().plot(kind="bar")

plt.title("Number of Properties by BHK")
plt.xlabel("BHK")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ### Business Insight
#
# 2 BHK and 3 BHK properties dominate the Bengaluru housing market, suggesting they represent the highest demand among buyers.

# %%
plt.savefig("../images/price_distribution.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Exploratory Data Analysis - Step 3
#
# ### Top 10 Locations by Average Property Price
#
# **Objective:**
#
# Identify the locations with the highest average property prices in Bengaluru. This helps understand premium residential areas and provides valuable insights for home buyers and real estate analysts.

# %%
top_locations = (
    df.groupby("location")["price"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

top_locations
# Out:
# location
# Cunningham Road          824.384615
# Malleshwaram             377.601923
# Kodihalli                367.733333
# Benson Town              346.743333
# Rajaji Nagar             338.298614
# Indira Nagar             290.904762
# Sarakki Nagar            254.710000
# Ulsoor                   252.888889
# Frazer Town              248.641429
# Banashankari Stage II    245.894286
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,6))

top_locations.plot(kind="bar")

plt.title("Top 10 Most Expensive Locations")
plt.xlabel("Location")
plt.ylabel("Average Price (Lakhs)")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Business Insight
#
# The chart highlights Bengaluru's premium residential locations with the highest average property prices. These areas are likely to offer better infrastructure, connectivity, and amenities, making them attractive to high-income buyers and investors.

# %%
cheapest_locations = (
    df.groupby("location")["price"]
    .mean()
    .sort_values()
    .head(10)
)

cheapest_locations
# Out:
# location
# Ananth Nagar                   33.406786
# Kereguddadahalli               34.206667
# Chandapura                     35.475380
# Kammasandra                    38.054483
# Anekal                         38.333333
# Bommasandra Industrial Area    40.949615
# Dommasandra                    41.028462
# Bisuvanahalli                  41.365366
# Doddathoguru                   44.323793
# Kambipura                      44.734000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,6))

cheapest_locations.plot(kind="bar")

plt.title("Top 10 Most Affordable Locations")
plt.xlabel("Location")
plt.ylabel("Average Price (Lakhs)")

plt.xticks(rotation=45)

plt.show()

# %%
### Business Insight

Affordable locations may be suitable for first-time home buyers, students, or budget-conscious families. However, affordability should be evaluated alongside connectivity and amenities, which will be incorporated later through the CityLife Score.
# Out:
#   Cell In[95], line 3
#     Affordable locations may be suitable for first-time home buyers, students, or budget-conscious families. However, affordability should be evaluated alongside connectivity and amenities, which will be incorporated later through the CityLife Score.
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Business Insight
#
# Affordable locations may be suitable for first-time home buyers, students, or budget-conscious families. However, affordability should be evaluated alongside connectivity and amenities, which will be incorporated later through the CityLife Score.

# %%
plt.figure(figsize=(10,6))
plt.hist(df["price"], bins=50)

plt.title("Distribution of House Prices")
plt.xlabel("Price (Lakhs)")
plt.ylabel("Number of Properties")

plt.savefig("../images/price_distribution.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.savefig("../images/bhk_distribution.png", dpi=300, bbox_inches="tight")

# %%
## Price Distribution

![Price Distribution](images/price_distribution.png)

---

## BHK Distribution

![BHK Distribution](images/bhk_distribution.png)
# Out:
#   Cell In[98], line 5
#     ---
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Price Distribution
#
# ![Price Distribution](images/price_distribution.png)
#
# ---
#
# ## BHK Distribution
#
# ![BHK Distribution](images/bhk_distribution.png)

# %% [markdown]
# ## Exploratory Data Analysis - Step 5
#
# ### Price Distribution by BHK
#
# **Objective:**
#
# Analyze how property prices vary across different BHK configurations. This helps understand market trends and buyer preferences.

# %%
plt.figure(figsize=(10,6))

df.boxplot(column="price", by="bhk")

plt.title("Price Distribution by BHK")
plt.suptitle("")  # Removes automatic title
plt.xlabel("BHK")
plt.ylabel("Price (Lakhs)")

plt.show()

# %% [markdown]
# ### Business Insight
#
# Properties with higher BHK configurations generally have higher prices. However, the presence of outliers indicates that factors such as location, amenities, and luxury features also influence property prices.

# %% [markdown]
# ## Exploratory Data Analysis - Step 6
#
# ### Total Square Feet vs Property Price
#
# **Objective:**
#
# Examine the relationship between property size and price to understand whether larger homes generally command higher prices.

# %%
plt.figure(figsize=(10,6))

plt.scatter(df["total_sqft"], df["price"], alpha=0.5)

plt.title("Total Square Feet vs Price")
plt.xlabel("Total Square Feet")
plt.ylabel("Price (Lakhs)")

plt.show()

# %% [markdown]
# ### Business Insight
#
# There is a positive relationship between property size and price. Larger homes generally cost more, although location and other factors introduce variation.

# %%
numeric_df = df.select_dtypes(include=["number"])

numeric_df.corr()
# Out:
#                 total_sqft      bath   balcony     price       bhk  \
# total_sqft        1.000000  0.527493  0.157932  0.581889  0.517471
# bath              0.527493  1.000000  0.239102  0.525717  0.866131
# balcony           0.157932  0.239102  1.000000  0.122830  0.243837
# price             0.581889  0.525717  0.122830  1.000000  0.479421
# bhk               0.517471  0.866131  0.243837  0.479421  1.000000
# price_per_sqft    0.203449  0.330800  0.036034  0.694602  0.296055
# sqft_per_bhk      0.741035  0.099596  0.022914  0.304633  0.027593
#
#                 price_per_sqft  sqft_per_bhk
# total_sqft            0.203449      0.741035
# bath                  0.330800      0.099596
# balcony               0.036034      0.022914
# price                 0.694602      0.304633
# bhk                   0.296055      0.027593
# price_per_sqft        1.000000      0.065794
# sqft_per_bhk          0.065794      1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.imshow(numeric_df.corr(), cmap="coolwarm")

plt.colorbar()

plt.xticks(range(len(numeric_df.columns)), numeric_df.columns, rotation=90)
plt.yticks(range(len(numeric_df.columns)), numeric_df.columns)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ### Business Insight
#
# The correlation matrix highlights relationships among numerical variables. Features with stronger correlations to price may be more useful for predicting property values and understanding market trends.

# %%
git add .
git commit -m "Completed Advanced EDA visualizations"
git push
# Out:
#   Cell In[103], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %%
cd C:\Users\Sanjana\Documents\UrbanIQ
# Out:
# [WinError 3] The system cannot find the path specified: 'C:\\Users\\Sanjana\\Documents\\UrbanIQ'
# C:\Users\sanja\UrbanIQ\notebooks

# %%
git add .
git commit -m "Completed Advanced EDA visualizations"
git push
# Out:
#   Cell In[105], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Exploratory Data Analysis - Step 8
#
# ### Average Price by BHK
#
# **Objective:**
#
# Analyze how the average property price changes with the number of bedrooms (BHK).

# %%
avg_price_bhk = df.groupby("bhk")["price"].mean()

avg_price_bhk
# Out:
# bhk
# 1      44.831170
# 2      60.114831
# 3     112.944484
# 4     293.013747
# 5     382.724138
# 6     323.043956
# 7     366.285714
# 8     297.680000
# 9     342.466667
# 10    897.500000
# 11    255.000000
# 13    275.000000
# 16    550.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,5))

avg_price_bhk.plot(kind="bar")

plt.title("Average Property Price by BHK")
plt.xlabel("BHK")
plt.ylabel("Average Price (Lakhs)")

plt.savefig("../images/avg_price_by_bhk.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Exploratory Data Analysis - Step 9
#
# ### Price per Square Foot Distribution
#
# **Objective:**
#
# Understand how property prices per square foot are distributed across Bengaluru.

# %%
plt.figure(figsize=(10,6))

plt.hist(df["price_per_sqft"], bins=50)

plt.title("Price per Square Foot Distribution")
plt.xlabel("Price per Sqft")
plt.ylabel("Number of Properties")

plt.savefig("../images/price_per_sqft_distribution.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
top_locations = df["location"].value_counts().head(10)

top_locations
# Out:
# location
# Other                    2758
# Whitefield                520
# Sarjapur  Road            373
# Electronic City           280
# Kanakpura Road            238
# Thanisandra               230
# Yelahanka                 204
# Marathahalli              164
# Hebbal                    160
# Raja Rajeshwari Nagar     158
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))

top_locations.plot(kind="bar")

plt.title("Top 10 Locations by Number of Properties")
plt.xlabel("Location")
plt.ylabel("Number of Properties")

plt.xticks(rotation=45)

plt.savefig("../images/top_locations.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.savefig("../images/chart_name.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.savefig("../images/bhk_distribution.png", dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(10,6))

# Your plotting code
...

plt.title("Chart Title")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Save the chart
plt.savefig("../images/chart_name.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.figure(figsize=(12,6))

top_locations.plot(kind="bar")

plt.title("Top 10 Most Expensive Locations")
plt.xlabel("Location")
plt.ylabel("Average Price (Lakhs)")
plt.xticks(rotation=45)

# Save the chart
plt.savefig("../images/top_10_expensive_locations.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Exploratory Data Analysis - Step 10
#
# ### Correlation Heatmap
#
# **Objective:**
#
# Analyze the relationships between numerical features in the dataset. A correlation heatmap helps identify which variables are strongly related to property prices and each other.

# %%
numeric_df = df.select_dtypes(include=["number"])

corr = numeric_df.corr()

plt.figure(figsize=(8,6))

plt.imshow(corr, cmap="coolwarm")

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Heatmap")

# Save the chart
plt.savefig("../images/correlation_heatmap.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### Business Insight
#
# The heatmap shows how numerical features are related to each other. Variables with stronger positive or negative correlations to price can provide valuable insights for understanding the housing market and may be useful in future predictive models.

# %% [markdown]
# ## Exploratory Data Analysis - Step 11
#
# ### Average Property Price by Top 10 Locations
#
# **Objective:**
#
# Compare the average property prices across the top 10 locations to identify premium residential areas.

# %%
top10_avg_price = (
    df.groupby("location")["price"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(12,6))

top10_avg_price.plot(kind="bar")

plt.title("Average Property Price - Top 10 Locations")
plt.xlabel("Location")
plt.ylabel("Average Price (Lakhs)")
plt.xticks(rotation=45)

# Save the chart
plt.savefig("../images/average_price_top10_locations.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### Business Insight
#
# Premium locations have significantly higher average property prices. These areas are likely to have better infrastructure, accessibility, and amenities, making them attractive to buyers and investors.

# %%
df.to_csv("../data/cleaned_bengaluru_housing.csv", index=False)

# %%
df.to_csv("../data/cleaned_bengaluru_housing.csv", index=False)
